# %% [markdown]
# <a href="https://colab.research.google.com/github/WaRdenLF/week1lab/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Please update the information, and submit your work

# %%
my_name = "奥伊贝克"

# %%
my_enrollment_number = "A85204925024"

# %%
my_hobby = "learning Chinese"

# %%
print("Hello, my name is {}, and my my enrollment number is {}. I like {}.".format(my_name, my_enrollment_number, my_hobby))
# Out:
# Hello, my name is 奥伊贝克, and my my enrollment number is A85204925024. I like learning Chinese.
